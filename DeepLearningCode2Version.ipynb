# %%
import os
import pandas as pd
import numpy as np
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
import torchvision.models as models
from PIL import Image, ImageDraw
import random
from collections import defaultdict

# %%
class RoadSignDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transform=None, unknown_transform=None, unknown_crop_size=(224, 224), unknown_samples_per_image=1, is_validation=False):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.transform = transform
        self.unknown_transform = unknown_transform
        self.unknown_crop_size = unknown_crop_size
        self.unknown_samples_per_image = unknown_samples_per_image
        self.is_validation = is_validation
        self.images = [f for f in os.listdir(images_dir) if f.endswith('.jpg')]
        self.annotations = self._load_annotations()
        print(f"Loaded {len(self.images)} images with annotations")

    def _load_annotations(self):
        annotations = {}
        for img_file in self.images:
            img_name = os.path.splitext(img_file)[0]
            label_file = os.path.join(self.labels_dir, img_name + '.csv')
            try:
                df = pd.read_csv(label_file, header=None)
                if df.empty:
                    annotations[img_file] = "unknown"
                else:
                    df = df[~df[4].str.lower().isin(['ff'])]
                    annotations[img_file] = df.values.tolist()
                print(f"Processed {label_file}, found {len(annotations[img_file]) if annotations[img_file] != 'unknown' else 'unknown'} annotations")
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: {label_file}")
                annotations[img_file] = "unknown"
            except Exception as e:
                print(f"Error processing {label_file}: {e}")
                annotations[img_file] = "unknown"
        return annotations

    def _get_unknown_crops(self, image, label_boxes):
        if self.is_validation:
            return []
        width, height = image.size
        crops = []
        if width < self.unknown_crop_size[0] or height < self.unknown_crop_size[1]:
            print(f"Skipping unknown crop for image of size ({width}, {height})")
            return crops
        for _ in range(self.unknown_samples_per_image):
            attempts = 0
            while attempts < 10:
                left = random.randint(0, width - self.unknown_crop_size[0])
                top = random.randint(0, height - self.unknown_crop_size[1])
                right = left + self.unknown_crop_size[0]
                bottom = top + self.unknown_crop_size[1]
                crop_box = (left, top, right, bottom)
                if not any(self._boxes_intersect(crop_box, box) for box in label_boxes):
                    crop = image.crop(crop_box)
                    if self.unknown_transform:
                        crop = self.unknown_transform(crop)
                    crops.append(crop)
                    break
                attempts += 1
        return crops

    def _boxes_intersect(self, boxA, boxB):
        leftA, topA, rightA, bottomA = boxA
        leftB, topB, rightB, bottomB = boxB
        return not (leftA >= rightB or rightA <= leftB or topA >= bottomB or bottomA <= topB)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_file = self.images[idx]
        img_path = os.path.join(self.images_dir, img_file)
        image = Image.open(img_path).convert('RGB')
        #print(f"Loading image: {img_path}")

        labels = self.annotations[img_file]
        crops = []
        categories = []

        if labels == "unknown":
            if self.unknown_transform:
                image = self.unknown_transform(image)
            else:
                image = self.transform(image) if self.transform else image
            crops.append(image)
            categories.append("unknown")
        else:
            label_boxes = []
            for label in labels:
                if len(label) == 5:
                    x1, y1, x2, y2, category = label
                    label_boxes.append((x1, y1, x2, y2))
                    crop = image.crop((x1, y1, x2, y2))
                    if self.transform:
                        crop = self.transform(crop)
                    crops.append(crop)
                    categories.append(category)
                else:
                    print(f"Skipping invalid label: {label}")

            unknown_crops = self._get_unknown_crops(image, label_boxes)
            crops.extend(unknown_crops)
            categories.extend(["unknown"] * len(unknown_crops))

        return crops, categories



def custom_collate_fn(batch):
    crops = [item[0] for item in batch]
    categories = [item[1] for item in batch]
    crops = [crop for sublist in crops for crop in sublist]
    categories = [category for sublist in categories for category in sublist]
    return crops, categories

#calculer le nombre des labels dans un dataset
def count_labels_in_dataset(dataset):
    label_counts = defaultdict(int)
    for i in range(len(dataset)):
        _, categories = dataset[i]
        for category in categories:
            label_counts[category] += 1
    return label_counts

# %%
images_dir = './train/images'
labels_dir = './train/labels'
val_images_dir = './val/images'
val_labels_dir = './val/labels'

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

unknown_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
    transforms.RandomRotation(degrees=15),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])
#training
dataset = RoadSignDataset(images_dir, labels_dir, transform=transform, unknown_transform=unknown_transform, unknown_samples_per_image=1,is_validation=False)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)
#validation
val_dataset = RoadSignDataset(val_images_dir, val_labels_dir, transform=transform, unknown_transform=unknown_transform, unknown_samples_per_image=1,is_validation=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=custom_collate_fn)

for batch in dataloader:
    crops, categories = batch
    for crop, category in zip(crops, categories):
        print(crop.shape, category)
# Out:
# Processed ./train/labels\0001.csv, found 2 annotations
# Processed ./train/labels\0002.csv, found 1 annotations
# Processed ./train/labels\0003.csv, found 4 annotations
# Processed ./train/labels\0005.csv, found 3 annotations
# Processed ./train/labels\0006.csv, found 2 annotations
# Processed ./train/labels\0007.csv, found 3 annotations
# Processed ./train/labels\0008.csv, found 4 annotations
# Processed ./train/labels\0009.csv, found 4 annotations
# EmptyDataError: ./train/labels\0010.csv
# Processed ./train/labels\0011.csv, found 1 annotations
# Processed ./train/labels\0012.csv, found 1 annotations
# Processed ./train/labels\0013.csv, found 1 annotations
# Processed ./train/labels\0014.csv, found 1 annotations
# Processed ./train/labels\0015.csv, found 2 annotations
# EmptyDataError: ./train/labels\0016.csv
# Processed ./train/labels\0017.csv, found 3 annotations
# EmptyDataError: ./train/labels\0018.csv
# Processed ./train/labels\0019.csv, found 1 annotations
# Processed ./train/labels\0020.csv, found 2 annotations
# Processed ./train/labels\0021.csv, found 1 annotations
# Processed ./train/labels\0022.csv, found 1 annotations
# EmptyDataError: ./train/labels\0023.csv
# Processed ./train/labels\0024.csv, found 1 annotations
# Processed ./train/labels\0025.csv, found 1 annotations
# Processed ./train/labels\0026.csv, found 1 annotations
# Processed ./train/labels\0027.csv, found 1 annotations
# EmptyDataError: ./train/labels\0028.csv
# Processed ./train/labels\0029.csv, found 2 annotations
# Processed ./train/labels\0030.csv, found 1 annotations
# Processed ./train/labels\0031.csv, found 1 annotations
# Processed ./train/labels\0032.csv, found 1 annotations
# Processed ./train/labels\0033.csv, found 1 annotations
# Processed ./train/labels\0034.csv, found 1 annotations
# Processed ./train/labels\0035.csv, found 1 annotations
# Processed ./train/labels\0036.csv, found 1 annotations
# Processed ./train/labels\0037.csv, found 1 annotations
# Processed ./train/labels\0038.csv, found 1 annotations
# Processed ./train/labels\0040.csv, found 2 annotations
# EmptyDataError: ./train/labels\0041.csv
# Processed ./train/labels\0042.csv, found 1 annotations
# Processed ./train/labels\0043.csv, found 1 annotations
# Processed ./train/labels\0044.csv, found 3 annotations
# Processed ./train/labels\0046.csv, found 1 annotations
# Processed ./train/labels\0048.csv, found 1 annotations
# Processed ./train/labels\0049.csv, found 1 annotations
# Processed ./train/labels\0050.csv, found 1 annotations
# Processed ./train/labels\0051.csv, found 1 annotations
# EmptyDataError: ./train/labels\0052.csv
# Processed ./train/labels\0053.csv, found 1 annotations
# Processed ./train/labels\0055.csv, found 2 annotations
# Processed ./train/labels\0056.csv, found 1 annotations
# Processed ./train/labels\0057.csv, found 3 annotations
# Processed ./train/labels\0058.csv, found 1 annotations
# Processed ./train/labels\0059.csv, found 1 annotations
# Processed ./train/labels\0060.csv, found 2 annotations
# Processed ./train/labels\0061.csv, found 1 annotations
# Processed ./train/labels\0062.csv, found 1 annotations
# Processed ./train/labels\0064.csv, found 2 annotations
# Processed ./train/labels\0065.csv, found 2 annotations
# Processed ./train/labels\0066.csv, found 1 annotations
# Processed ./train/labels\0067.csv, found 1 annotations
# Processed ./train/labels\0068.csv, found 1 annotations
# Processed ./train/labels\0069.csv, found 1 annotations
# Processed ./train/labels\0071.csv, found 1 annotations
# Processed ./train/labels\0072.csv, found 1 annotations
# Processed ./train/labels\0073.csv, found 2 annotations
# Processed ./train/labels\0075.csv, found 2 annotations
# Processed ./train/labels\0076.csv, found 1 annotations
# Processed ./train/labels\0077.csv, found 1 annotations
# EmptyDataError: ./train/labels\0078.csv
# Processed ./train/labels\0079.csv, found 2 annotations
# Processed ./train/labels\0081.csv, found 1 annotations
# Processed ./train/labels\0082.csv, found 1 annotations
# Processed ./train/labels\0085.csv, found 1 annotations
# Processed ./train/labels\0086.csv, found 1 annotations
# Processed ./train/labels\0089.csv, found 1 annotations
# Processed ./train/labels\0090.csv, found 1 annotations
# Processed ./train/labels\0092.csv, found 1 annotations
# EmptyDataError: ./train/labels\0093.csv
# Processed ./train/labels\0094.csv, found 1 annotations
# Processed ./train/labels\0095.csv, found 1 annotations
# Processed ./train/labels\0096.csv, found 1 annotations
# Processed ./train/labels\0097.csv, found 1 annotations
# Processed ./train/labels\0098.csv, found 1 annotations
# Processed ./train/labels\0100.csv, found 1 annotations
# Processed ./train/labels\0102.csv, found 1 annotations
# Processed ./train/labels\0103.csv, found 1 annotations
# Processed ./train/labels\0104.csv, found 1 annotations
# Processed ./train/labels\0105.csv, found 1 annotations
# Processed ./train/labels\0106.csv, found 2 annotations
# Processed ./train/labels\0107.csv, found 2 annotations
# Processed ./train/labels\0108.csv, found 1 annotations
# EmptyDataError: ./train/labels\0109.csv
# Processed ./train/labels\0110.csv, found 2 annotations
# Processed ./train/labels\0111.csv, found 1 annotations
# EmptyDataError: ./train/labels\0112.csv
# Processed ./train/labels\0114.csv, found 1 annotations
# Processed ./train/labels\0115.csv, found 1 annotations
# Processed ./train/labels\0116.csv, found 2 annotations
# Processed ./train/labels\0117.csv, found 2 annotations
# Processed ./train/labels\0118.csv, found 1 annotations
# Processed ./train/labels\0119.csv, found 1 annotations
# Processed ./train/labels\0120.csv, found 1 annotations
# Processed ./train/labels\0121.csv, found 1 annotations
# Processed ./train/labels\0122.csv, found 1 annotations
# Processed ./train/labels\0123.csv, found 1 annotations
# Processed ./train/labels\0124.csv, found 1 annotations
# Processed ./train/labels\0125.csv, found 1 annotations
# Processed ./train/labels\0126.csv, found 1 annotations
# Processed ./train/labels\0127.csv, found 2 annotations
# Processed ./train/labels\0129.csv, found 1 annotations
# Processed ./train/labels\0130.csv, found 1 annotations
# Processed ./train/labels\0134.csv, found 1 annotations
# Processed ./train/labels\0135.csv, found 2 annotations
# Processed ./train/labels\0136.csv, found 1 annotations
# Processed ./train/labels\0138.csv, found 1 annotations
# Processed ./train/labels\0142.csv, found 2 annotations
# Processed ./train/labels\0143.csv, found 1 annotations
# Processed ./train/labels\0144.csv, found 1 annotations
# Processed ./train/labels\0146.csv, found 1 annotations
# Processed ./train/labels\0147.csv, found 1 annotations
# Processed ./train/labels\0148.csv, found 1 annotations
# Processed ./train/labels\0150.csv, found 1 annotations
# Processed ./train/labels\0151.csv, found 2 annotations
# Processed ./train/labels\0152.csv, found 2 annotations
# Processed ./train/labels\0154.csv, found 2 annotations
# Processed ./train/labels\0156.csv, found 2 annotations
# Processed ./train/labels\0157.csv, found 1 annotations
# Processed ./train/labels\0158.csv, found 2 annotations
# Processed ./train/labels\0159.csv, found 1 annotations
# Processed ./train/labels\0160.csv, found 1 annotations
# Processed ./train/labels\0161.csv, found 1 annotations
# EmptyDataError: ./train/labels\0162.csv
# Processed ./train/labels\0163.csv, found 2 annotations
# Processed ./train/labels\0164.csv, found 1 annotations
# Processed ./train/labels\0166.csv, found 3 annotations
# EmptyDataError: ./train/labels\0167.csv
# Processed ./train/labels\0168.csv, found 1 annotations
# EmptyDataError: ./train/labels\0169.csv
# Processed ./train/labels\0170.csv, found 2 annotations
# Processed ./train/labels\0171.csv, found 2 annotations
# Processed ./train/labels\0172.csv, found 3 annotations
# EmptyDataError: ./train/labels\0175.csv
# Processed ./train/labels\0176.csv, found 3 annotations
# Processed ./train/labels\0177.csv, found 2 annotations
# Processed ./train/labels\0178.csv, found 1 annotations
# Processed ./train/labels\0180.csv, found 1 annotations
# Processed ./train/labels\0181.csv, found 1 annotations
# Processed ./train/labels\0182.csv, found 1 annotations
# Processed ./train/labels\0183.csv, found 1 annotations
# Processed ./train/labels\0185.csv, found 1 annotations
# Processed ./train/labels\0186.csv, found 1 annotations
# EmptyDataError: ./train/labels\0190.csv
# Processed ./train/labels\0191.csv, found 2 annotations
# Processed ./train/labels\0192.csv, found 1 annotations
# Processed ./train/labels\0193.csv, found 2 annotations
# EmptyDataError: ./train/labels\0194.csv
# Processed ./train/labels\0195.csv, found 1 annotations
# Processed ./train/labels\0197.csv, found 1 annotations
# Processed ./train/labels\0199.csv, found 3 annotations
# Processed ./train/labels\0200.csv, found 1 annotations
# Processed ./train/labels\0201.csv, found 1 annotations
# Processed ./train/labels\0202.csv, found 2 annotations
# Processed ./train/labels\0203.csv, found 1 annotations
# Processed ./train/labels\0204.csv, found 1 annotations
# Processed ./train/labels\0205.csv, found 1 annotations
# Processed ./train/labels\0206.csv, found 2 annotations
# Processed ./train/labels\0207.csv, found 1 annotations
# Processed ./train/labels\0208.csv, found 1 annotations
# Processed ./train/labels\0209.csv, found 2 annotations
# Processed ./train/labels\0210.csv, found 2 annotations
# Processed ./train/labels\0211.csv, found 1 annotations
# Processed ./train/labels\0212.csv, found 1 annotations
# Processed ./train/labels\0213.csv, found 1 annotations
# Processed ./train/labels\0214.csv, found 2 annotations
# Processed ./train/labels\0217.csv, found 1 annotations
# Processed ./train/labels\0218.csv, found 1 annotations
# Processed ./train/labels\0219.csv, found 1 annotations
# EmptyDataError: ./train/labels\0220.csv
# Processed ./train/labels\0222.csv, found 1 annotations
# Processed ./train/labels\0223.csv, found 1 annotations
# Processed ./train/labels\0224.csv, found 1 annotations
# Processed ./train/labels\0225.csv, found 1 annotations
# Processed ./train/labels\0226.csv, found 2 annotations
# Processed ./train/labels\0230.csv, found 2 annotations
# Processed ./train/labels\0231.csv, found 1 annotations
# Processed ./train/labels\0232.csv, found 1 annotations
# Processed ./train/labels\0233.csv, found 2 annotations
# Processed ./train/labels\0234.csv, found 3 annotations
# Processed ./train/labels\0236.csv, found 1 annotations
# Processed ./train/labels\0237.csv, found 1 annotations
# Processed ./train/labels\0238.csv, found 2 annotations
# Processed ./train/labels\0241.csv, found 1 annotations
# Processed ./train/labels\0242.csv, found 1 annotations
# Processed ./train/labels\0243.csv, found 1 annotations
# Processed ./train/labels\0244.csv, found 1 annotations
# Processed ./train/labels\0245.csv, found 1 annotations
# Processed ./train/labels\0246.csv, found 3 annotations
# Processed ./train/labels\0247.csv, found 3 annotations
# Processed ./train/labels\0250.csv, found 2 annotations
# Processed ./train/labels\0251.csv, found 1 annotations
# Processed ./train/labels\0252.csv, found 3 annotations
# Processed ./train/labels\0253.csv, found 2 annotations
# Processed ./train/labels\0254.csv, found 1 annotations
# Processed ./train/labels\0255.csv, found 1 annotations
# EmptyDataError: ./train/labels\0256.csv
# Processed ./train/labels\0258.csv, found 4 annotations
# Processed ./train/labels\0259.csv, found 2 annotations
# Processed ./train/labels\0260.csv, found 2 annotations
# Processed ./train/labels\0261.csv, found 2 annotations
# Processed ./train/labels\0262.csv, found 1 annotations
# Processed ./train/labels\0264.csv, found 1 annotations
# Processed ./train/labels\0265.csv, found 2 annotations
# Processed ./train/labels\0266.csv, found 2 annotations
# Processed ./train/labels\0267.csv, found 1 annotations
# Processed ./train/labels\0268.csv, found 1 annotations
# Processed ./train/labels\0271.csv, found 1 annotations
# Processed ./train/labels\0273.csv, found 1 annotations
# Processed ./train/labels\0274.csv, found 1 annotations
# Processed ./train/labels\0275.csv, found 1 annotations
# Processed ./train/labels\0276.csv, found 1 annotations
# Processed ./train/labels\0277.csv, found 1 annotations
# Processed ./train/labels\0278.csv, found 1 annotations
# Processed ./train/labels\0279.csv, found 1 annotations
# Processed ./train/labels\0280.csv, found 2 annotations
# EmptyDataError: ./train/labels\0281.csv
# Processed ./train/labels\0282.csv, found 1 annotations
# Processed ./train/labels\0283.csv, found 1 annotations
# Processed ./train/labels\0285.csv, found 3 annotations
# Processed ./train/labels\0286.csv, found 1 annotations
# Processed ./train/labels\0287.csv, found 1 annotations
# Processed ./train/labels\0288.csv, found 4 annotations
# Processed ./train/labels\0289.csv, found 3 annotations
# Processed ./train/labels\0290.csv, found 1 annotations
# Processed ./train/labels\0292.csv, found 1 annotations
# Processed ./train/labels\0293.csv, found 3 annotations
# Processed ./train/labels\0294.csv, found 1 annotations
# Processed ./train/labels\0295.csv, found 1 annotations
# Processed ./train/labels\0298.csv, found 1 annotations
# Processed ./train/labels\0299.csv, found 3 annotations
# Processed ./train/labels\0300.csv, found 3 annotations
# Processed ./train/labels\0301.csv, found 2 annotations
# Processed ./train/labels\0302.csv, found 1 annotations
# Processed ./train/labels\0303.csv, found 2 annotations
# Processed ./train/labels\0304.csv, found 1 annotations
# EmptyDataError: ./train/labels\0305.csv
# Processed ./train/labels\0306.csv, found 1 annotations
# Processed ./train/labels\0307.csv, found 2 annotations
# Processed ./train/labels\0308.csv, found 1 annotations
# Processed ./train/labels\0309.csv, found 2 annotations
# Processed ./train/labels\0311.csv, found 2 annotations
# Processed ./train/labels\0312.csv, found 2 annotations
# Processed ./train/labels\0315.csv, found 1 annotations
# Processed ./train/labels\0317.csv, found 2 annotations
# Processed ./train/labels\0318.csv, found 2 annotations
# Processed ./train/labels\0319.csv, found 2 annotations
# Processed ./train/labels\0320.csv, found 3 annotations
# Processed ./train/labels\0321.csv, found 1 annotations
# Processed ./train/labels\0322.csv, found 2 annotations
# Processed ./train/labels\0324.csv, found 2 annotations
# Processed ./train/labels\0326.csv, found 2 annotations
# Processed ./train/labels\0328.csv, found 1 annotations
# Processed ./train/labels\0329.csv, found 1 annotations
# Processed ./train/labels\0331.csv, found 1 annotations
# Processed ./train/labels\0332.csv, found 1 annotations
# Processed ./train/labels\0334.csv, found 2 annotations
# Processed ./train/labels\0336.csv, found 2 annotations
# Processed ./train/labels\0337.csv, found 1 annotations
# Processed ./train/labels\0338.csv, found 1 annotations
# Processed ./train/labels\0339.csv, found 1 annotations
# Processed ./train/labels\0340.csv, found 2 annotations
# Processed ./train/labels\0341.csv, found 1 annotations
# Processed ./train/labels\0344.csv, found 1 annotations
# Processed ./train/labels\0345.csv, found 1 annotations
# Processed ./train/labels\0346.csv, found 1 annotations
# Processed ./train/labels\0347.csv, found 2 annotations
# Processed ./train/labels\0348.csv, found 1 annotations
# Processed ./train/labels\0349.csv, found 1 annotations
# Processed ./train/labels\0350.csv, found 1 annotations
# Processed ./train/labels\0351.csv, found 1 annotations
# Processed ./train/labels\0352.csv, found 3 annotations
# EmptyDataError: ./train/labels\0353.csv
# Processed ./train/labels\0354.csv, found 5 annotations
# Processed ./train/labels\0356.csv, found 1 annotations
# Processed ./train/labels\0357.csv, found 1 annotations
# Processed ./train/labels\0359.csv, found 1 annotations
# Processed ./train/labels\0361.csv, found 1 annotations
# Processed ./train/labels\0362.csv, found 1 annotations
# EmptyDataError: ./train/labels\0363.csv
# Processed ./train/labels\0364.csv, found 2 annotations
# Processed ./train/labels\0365.csv, found 2 annotations
# Processed ./train/labels\0366.csv, found 2 annotations
# Processed ./train/labels\0367.csv, found 2 annotations
# Processed ./train/labels\0368.csv, found 1 annotations
# Processed ./train/labels\0369.csv, found 2 annotations
# EmptyDataError: ./train/labels\0370.csv
# Processed ./train/labels\0371.csv, found 1 annotations
# Processed ./train/labels\0372.csv, found 1 annotations
# Processed ./train/labels\0373.csv, found 1 annotations
# Processed ./train/labels\0375.csv, found 1 annotations
# Processed ./train/labels\0376.csv, found 2 annotations
# Processed ./train/labels\0377.csv, found 2 annotations
# EmptyDataError: ./train/labels\0378.csv
# Processed ./train/labels\0380.csv, found 2 annotations
# Processed ./train/labels\0381.csv, found 2 annotations
# Processed ./train/labels\0382.csv, found 1 annotations
# Processed ./train/labels\0384.csv, found 2 annotations
# Processed ./train/labels\0386.csv, found 1 annotations
# Processed ./train/labels\0387.csv, found 2 annotations
# Processed ./train/labels\0388.csv, found 2 annotations
# Processed ./train/labels\0389.csv, found 2 annotations
# Processed ./train/labels\0391.csv, found 3 annotations
# Processed ./train/labels\0392.csv, found 3 annotations
# EmptyDataError: ./train/labels\0393.csv
# Processed ./train/labels\0394.csv, found 1 annotations
# Processed ./train/labels\0396.csv, found 2 annotations
# Processed ./train/labels\0397.csv, found 6 annotations
# Processed ./train/labels\0398.csv, found 1 annotations
# Processed ./train/labels\0399.csv, found 1 annotations
# Processed ./train/labels\0400.csv, found 2 annotations
# Processed ./train/labels\0401.csv, found 1 annotations
# Processed ./train/labels\0402.csv, found 1 annotations
# Processed ./train/labels\0403.csv, found 1 annotations
# Processed ./train/labels\0404.csv, found 1 annotations
# Processed ./train/labels\0405.csv, found 2 annotations
# EmptyDataError: ./train/labels\0408.csv
# Processed ./train/labels\0409.csv, found 1 annotations
# Processed ./train/labels\0410.csv, found 1 annotations
# Processed ./train/labels\0411.csv, found 1 annotations
# Processed ./train/labels\0412.csv, found 2 annotations
# Processed ./train/labels\0414.csv, found 1 annotations
# Processed ./train/labels\0415.csv, found 1 annotations
# EmptyDataError: ./train/labels\0416.csv
# Processed ./train/labels\0417.csv, found 1 annotations
# Processed ./train/labels\0418.csv, found 1 annotations
# EmptyDataError: ./train/labels\0420.csv
# Processed ./train/labels\0421.csv, found 1 annotations
# Processed ./train/labels\0423.csv, found 1 annotations
# Processed ./train/labels\0424.csv, found 1 annotations
# Processed ./train/labels\0425.csv, found 1 annotations
# Processed ./train/labels\0426.csv, found 1 annotations
# Processed ./train/labels\0429.csv, found 1 annotations
# Processed ./train/labels\0430.csv, found 1 annotations
# EmptyDataError: ./train/labels\0431.csv
# Processed ./train/labels\0432.csv, found 1 annotations
# Processed ./train/labels\0433.csv, found 1 annotations
# Processed ./train/labels\0434.csv, found 2 annotations
# Processed ./train/labels\0437.csv, found 1 annotations
# Processed ./train/labels\0438.csv, found 1 annotations
# Processed ./train/labels\0439.csv, found 1 annotations
# Processed ./train/labels\0440.csv, found 2 annotations
# Processed ./train/labels\0441.csv, found 1 annotations
# Processed ./train/labels\0443.csv, found 1 annotations
# Processed ./train/labels\0445.csv, found 1 annotations
# Processed ./train/labels\0447.csv, found 1 annotations
# Processed ./train/labels\0448.csv, found 2 annotations
# Processed ./train/labels\0450.csv, found 1 annotations
# Processed ./train/labels\0451.csv, found 2 annotations
# Processed ./train/labels\0452.csv, found 1 annotations
# Processed ./train/labels\0453.csv, found 1 annotations
# Processed ./train/labels\0454.csv, found 1 annotations
# Processed ./train/labels\0455.csv, found 1 annotations
# EmptyDataError: ./train/labels\0456.csv
# Processed ./train/labels\0457.csv, found 2 annotations
# Processed ./train/labels\0458.csv, found 1 annotations
# Processed ./train/labels\0460.csv, found 2 annotations
# Processed ./train/labels\0461.csv, found 1 annotations
# Processed ./train/labels\0463.csv, found 3 annotations
# EmptyDataError: ./train/labels\0464.csv
# EmptyDataError: ./train/labels\0465.csv
# Processed ./train/labels\0466.csv, found 1 annotations
# Processed ./train/labels\0467.csv, found 4 annotations
# Processed ./train/labels\0468.csv, found 1 annotations
# Processed ./train/labels\0469.csv, found 4 annotations
# Processed ./train/labels\0470.csv, found 1 annotations
# Processed ./train/labels\0472.csv, found 3 annotations
# Processed ./train/labels\0473.csv, found 1 annotations
# Processed ./train/labels\0476.csv, found 1 annotations
# Processed ./train/labels\0477.csv, found 2 annotations
# Processed ./train/labels\0480.csv, found 1 annotations
# Processed ./train/labels\0481.csv, found 1 annotations
# Processed ./train/labels\0482.csv, found 2 annotations
# Processed ./train/labels\0483.csv, found 3 annotations
# Processed ./train/labels\0484.csv, found 1 annotations
# Processed ./train/labels\0485.csv, found 1 annotations
# Processed ./train/labels\0486.csv, found 1 annotations
# EmptyDataError: ./train/labels\0489.csv
# Processed ./train/labels\0490.csv, found 1 annotations
# Processed ./train/labels\0491.csv, found 2 annotations
# Processed ./train/labels\0492.csv, found 1 annotations
# Processed ./train/labels\0493.csv, found 1 annotations
# Processed ./train/labels\0494.csv, found 2 annotations
# Processed ./train/labels\0495.csv, found 1 annotations
# Processed ./train/labels\0496.csv, found 2 annotations
# Processed ./train/labels\0497.csv, found 3 annotations
# Processed ./train/labels\0498.csv, found 1 annotations
# Processed ./train/labels\0499.csv, found 1 annotations
# Processed ./train/labels\0500.csv, found 1 annotations
# Processed ./train/labels\0502.csv, found 1 annotations
# Processed ./train/labels\0503.csv, found 3 annotations
# Processed ./train/labels\0504.csv, found 2 annotations
# Processed ./train/labels\0505.csv, found 2 annotations
# Processed ./train/labels\0507.csv, found 1 annotations
# Processed ./train/labels\0508.csv, found 1 annotations
# Processed ./train/labels\0509.csv, found 1 annotations
# Processed ./train/labels\0510.csv, found 1 annotations
# EmptyDataError: ./train/labels\0511.csv
# EmptyDataError: ./train/labels\0512.csv
# Processed ./train/labels\0513.csv, found 1 annotations
# Processed ./train/labels\0514.csv, found 1 annotations
# Processed ./train/labels\0516.csv, found 1 annotations
# Processed ./train/labels\0517.csv, found 1 annotations
# Processed ./train/labels\0518.csv, found 2 annotations
# Processed ./train/labels\0519.csv, found 2 annotations
# Processed ./train/labels\0520.csv, found 1 annotations
# EmptyDataError: ./train/labels\0521.csv
# Processed ./train/labels\0522.csv, found 1 annotations
# Processed ./train/labels\0523.csv, found 1 annotations
# Processed ./train/labels\0524.csv, found 1 annotations
# Processed ./train/labels\0525.csv, found 1 annotations
# Processed ./train/labels\0526.csv, found 1 annotations
# Processed ./train/labels\0527.csv, found 2 annotations
# Processed ./train/labels\0528.csv, found 1 annotations
# Processed ./train/labels\0529.csv, found 2 annotations
# Processed ./train/labels\0530.csv, found 2 annotations
# Processed ./train/labels\0531.csv, found 1 annotations
# Processed ./train/labels\0532.csv, found 1 annotations
# Processed ./train/labels\0534.csv, found 1 annotations
# Processed ./train/labels\0535.csv, found 1 annotations
# Processed ./train/labels\0536.csv, found 3 annotations
# EmptyDataError: ./train/labels\0538.csv
# Processed ./train/labels\0540.csv, found 1 annotations
# EmptyDataError: ./train/labels\0542.csv
# Processed ./train/labels\0543.csv, found 2 annotations
# Processed ./train/labels\0544.csv, found 5 annotations
# Processed ./train/labels\0545.csv, found 2 annotations
# Processed ./train/labels\0546.csv, found 2 annotations
# Processed ./train/labels\0548.csv, found 1 annotations
# EmptyDataError: ./train/labels\0549.csv
# Processed ./train/labels\0550.csv, found 1 annotations
# Processed ./train/labels\0551.csv, found 2 annotations
# Processed ./train/labels\0552.csv, found 2 annotations
# Processed ./train/labels\0553.csv, found 2 annotations
# Processed ./train/labels\0554.csv, found 1 annotations
# Processed ./train/labels\0555.csv, found 3 annotations
# Processed ./train/labels\0556.csv, found 2 annotations
# Processed ./train/labels\0558.csv, found 1 annotations
# Processed ./train/labels\0559.csv, found 1 annotations
# Processed ./train/labels\0561.csv, found 2 annotations
# Processed ./train/labels\0562.csv, found 1 annotations
# Processed ./train/labels\0563.csv, found 2 annotations
# Processed ./train/labels\0564.csv, found 1 annotations
# Processed ./train/labels\0565.csv, found 1 annotations
# Processed ./train/labels\0566.csv, found 1 annotations
# Processed ./train/labels\0567.csv, found 1 annotations
# Processed ./train/labels\0569.csv, found 1 annotations
# Processed ./train/labels\0570.csv, found 1 annotations
# Processed ./train/labels\0571.csv, found 2 annotations
# Processed ./train/labels\0572.csv, found 1 annotations
# Processed ./train/labels\0573.csv, found 1 annotations
# Processed ./train/labels\0574.csv, found 1 annotations
# Processed ./train/labels\0575.csv, found 1 annotations
# Processed ./train/labels\0577.csv, found 2 annotations
# Processed ./train/labels\0578.csv, found 1 annotations
# Processed ./train/labels\0579.csv, found 2 annotations
# Processed ./train/labels\0580.csv, found 1 annotations
# Processed ./train/labels\0581.csv, found 1 annotations
# Processed ./train/labels\0583.csv, found 2 annotations
# Processed ./train/labels\0584.csv, found 2 annotations
# Processed ./train/labels\0586.csv, found 1 annotations
# Processed ./train/labels\0588.csv, found 1 annotations
# Processed ./train/labels\0589.csv, found 1 annotations
# Processed ./train/labels\0590.csv, found 1 annotations
# Processed ./train/labels\0591.csv, found 2 annotations
# Processed ./train/labels\0592.csv, found 1 annotations
# Processed ./train/labels\0593.csv, found 1 annotations
# Processed ./train/labels\0594.csv, found 1 annotations
# EmptyDataError: ./train/labels\0596.csv
# Processed ./train/labels\0597.csv, found 1 annotations
# Processed ./train/labels\0598.csv, found 1 annotations
# Processed ./train/labels\0599.csv, found 2 annotations
# EmptyDataError: ./train/labels\0600.csv
# Processed ./train/labels\0602.csv, found 1 annotations
# Processed ./train/labels\0604.csv, found 1 annotations
# Processed ./train/labels\0605.csv, found 3 annotations
# Processed ./train/labels\0607.csv, found 1 annotations
# Processed ./train/labels\0608.csv, found 2 annotations
# Processed ./train/labels\0609.csv, found 5 annotations
# Processed ./train/labels\0610.csv, found 2 annotations
# Processed ./train/labels\0611.csv, found 1 annotations
# Processed ./train/labels\0612.csv, found 1 annotations
# Processed ./train/labels\0613.csv, found 1 annotations
# Processed ./train/labels\0614.csv, found 1 annotations
# Processed ./train/labels\0615.csv, found 1 annotations
# Processed ./train/labels\0616.csv, found 1 annotations
# Processed ./train/labels\0618.csv, found 1 annotations
# Processed ./train/labels\0620.csv, found 1 annotations
# Processed ./train/labels\0621.csv, found 5 annotations
# Processed ./train/labels\0622.csv, found 2 annotations
# Processed ./train/labels\0623.csv, found 1 annotations
# Processed ./train/labels\0624.csv, found 1 annotations
# Processed ./train/labels\0625.csv, found 1 annotations
# Processed ./train/labels\0626.csv, found 1 annotations
# Processed ./train/labels\0627.csv, found 1 annotations
# Processed ./train/labels\0628.csv, found 1 annotations
# Processed ./train/labels\0631.csv, found 2 annotations
# Processed ./train/labels\0632.csv, found 2 annotations
# Processed ./train/labels\0633.csv, found 2 annotations
# Processed ./train/labels\0634.csv, found 2 annotations
# Processed ./train/labels\0635.csv, found 1 annotations
# Processed ./train/labels\0636.csv, found 1 annotations
# Processed ./train/labels\0637.csv, found 1 annotations
# Processed ./train/labels\0638.csv, found 2 annotations
# Processed ./train/labels\0639.csv, found 2 annotations
# Processed ./train/labels\0640.csv, found 1 annotations
# Processed ./train/labels\0642.csv, found 2 annotations
# Processed ./train/labels\0643.csv, found 2 annotations
# EmptyDataError: ./train/labels\0644.csv
# Processed ./train/labels\0645.csv, found 1 annotations
# Processed ./train/labels\0646.csv, found 1 annotations
# Processed ./train/labels\0647.csv, found 1 annotations
# Processed ./train/labels\0648.csv, found 4 annotations
# Processed ./train/labels\0649.csv, found 1 annotations
# Processed ./train/labels\0650.csv, found 1 annotations
# Processed ./train/labels\0653.csv, found 4 annotations
# Processed ./train/labels\0654.csv, found 6 annotations
# Processed ./train/labels\0655.csv, found 1 annotations
# Processed ./train/labels\0657.csv, found 3 annotations
# Processed ./train/labels\0658.csv, found 1 annotations
# Processed ./train/labels\0659.csv, found 1 annotations
# Processed ./train/labels\0660.csv, found 2 annotations
# EmptyDataError: ./train/labels\0661.csv
# Processed ./train/labels\0662.csv, found 1 annotations
# Processed ./train/labels\0663.csv, found 1 annotations
# Processed ./train/labels\0664.csv, found 1 annotations
# Processed ./train/labels\0665.csv, found 5 annotations
# Processed ./train/labels\0666.csv, found 1 annotations
# Processed ./train/labels\0667.csv, found 1 annotations
# EmptyDataError: ./train/labels\0668.csv
# Processed ./train/labels\0669.csv, found 3 annotations
# Processed ./train/labels\0671.csv, found 1 annotations
# Processed ./train/labels\0672.csv, found 1 annotations
# Processed ./train/labels\0674.csv, found 1 annotations
# Processed ./train/labels\0675.csv, found 1 annotations
# Processed ./train/labels\0676.csv, found 3 annotations
# Processed ./train/labels\0677.csv, found 1 annotations
# EmptyDataError: ./train/labels\0678.csv
# Processed ./train/labels\0679.csv, found 1 annotations
# Processed ./train/labels\0682.csv, found 1 annotations
# Processed ./train/labels\0684.csv, found 2 annotations
# Processed ./train/labels\0685.csv, found 1 annotations
# Processed ./train/labels\0686.csv, found 1 annotations
# Processed ./train/labels\0687.csv, found 1 annotations
# Processed ./train/labels\0688.csv, found 2 annotations
# Processed ./train/labels\0689.csv, found 3 annotations
# Processed ./train/labels\0690.csv, found 1 annotations
# Processed ./train/labels\0692.csv, found 1 annotations
# Processed ./train/labels\0693.csv, found 2 annotations
# Processed ./train/labels\0696.csv, found 1 annotations
# Processed ./train/labels\0697.csv, found 5 annotations
# Processed ./train/labels\0699.csv, found 1 annotations
# Processed ./train/labels\0700.csv, found 3 annotations
# Processed ./train/labels\0702.csv, found 1 annotations
# Processed ./train/labels\0703.csv, found 6 annotations
# Processed ./train/labels\0704.csv, found 2 annotations
# Processed ./train/labels\0705.csv, found 1 annotations
# Processed ./train/labels\0706.csv, found 2 annotations
# Processed ./train/labels\0707.csv, found 1 annotations
# Processed ./train/labels\0708.csv, found 1 annotations
# Processed ./train/labels\0712.csv, found 1 annotations
# Processed ./train/labels\0714.csv, found 1 annotations
# Processed ./train/labels\0715.csv, found 1 annotations
# Processed ./train/labels\0716.csv, found 1 annotations
# Processed ./train/labels\0718.csv, found 2 annotations
# Processed ./train/labels\0719.csv, found 1 annotations
# Processed ./train/labels\0720.csv, found 1 annotations
# Processed ./train/labels\0721.csv, found 1 annotations
# Processed ./train/labels\0722.csv, found 1 annotations
# Processed ./train/labels\0723.csv, found 2 annotations
# Processed ./train/labels\0724.csv, found 3 annotations
# EmptyDataError: ./train/labels\0725.csv
# Processed ./train/labels\0726.csv, found 4 annotations
# Processed ./train/labels\0727.csv, found 1 annotations
# EmptyDataError: ./train/labels\0728.csv
# Processed ./train/labels\0729.csv, found 1 annotations
# Processed ./train/labels\0730.csv, found 1 annotations
# Processed ./train/labels\0731.csv, found 1 annotations
# Processed ./train/labels\0732.csv, found 2 annotations
# Processed ./train/labels\0734.csv, found 1 annotations
# Processed ./train/labels\0736.csv, found 1 annotations
# Processed ./train/labels\0737.csv, found 1 annotations
# Processed ./train/labels\0738.csv, found 1 annotations
# Processed ./train/labels\0740.csv, found 1 annotations
# Processed ./train/labels\0741.csv, found 1 annotations
# Processed ./train/labels\0742.csv, found 1 annotations
# Processed ./train/labels\0747.csv, found 1 annotations
# Processed ./train/labels\0749.csv, found 2 annotations
# Processed ./train/labels\0750.csv, found 2 annotations
# Processed ./train/labels\0751.csv, found 2 annotations
# Processed ./train/labels\0752.csv, found 3 annotations
# Processed ./train/labels\0753.csv, found 3 annotations
# Processed ./train/labels\0754.csv, found 1 annotations
# Processed ./train/labels\0755.csv, found 5 annotations
# Processed ./train/labels\0756.csv, found 1 annotations
# Processed ./train/labels\0758.csv, found 2 annotations
# Processed ./train/labels\0759.csv, found 3 annotations
# Processed ./train/labels\0760.csv, found 1 annotations
# Processed ./train/labels\0761.csv, found 1 annotations
# Processed ./train/labels\0762.csv, found 1 annotations
# Processed ./train/labels\0763.csv, found 2 annotations
# Processed ./train/labels\0764.csv, found 1 annotations
# Processed ./train/labels\0765.csv, found 1 annotations
# Processed ./train/labels\0767.csv, found 2 annotations
# EmptyDataError: ./train/labels\0768.csv
# Processed ./train/labels\0769.csv, found 2 annotations
# Processed ./train/labels\0770.csv, found 1 annotations
# Processed ./train/labels\0771.csv, found 1 annotations
# Processed ./train/labels\0772.csv, found 1 annotations
# Processed ./train/labels\0773.csv, found 2 annotations
# Processed ./train/labels\0774.csv, found 1 annotations
# Processed ./train/labels\0775.csv, found 2 annotations
# Processed ./train/labels\0776.csv, found 1 annotations
# Processed ./train/labels\0777.csv, found 1 annotations
# Processed ./train/labels\0778.csv, found 1 annotations
# Processed ./train/labels\0779.csv, found 1 annotations
# Processed ./train/labels\0780.csv, found 3 annotations
# EmptyDataError: ./train/labels\0781.csv
# Processed ./train/labels\0782.csv, found 5 annotations
# Processed ./train/labels\0783.csv, found 1 annotations
# Processed ./train/labels\0784.csv, found 2 annotations
# Processed ./train/labels\0785.csv, found 1 annotations
# EmptyDataError: ./train/labels\0786.csv
# Processed ./train/labels\0787.csv, found 1 annotations
# Processed ./train/labels\0788.csv, found 1 annotations
# Processed ./train/labels\0790.csv, found 1 annotations
# EmptyDataError: ./train/labels\0791.csv
# Processed ./train/labels\0792.csv, found 1 annotations
# Processed ./train/labels\0793.csv, found 1 annotations
# Processed ./train/labels\0794.csv, found 2 annotations
# Processed ./train/labels\0795.csv, found 1 annotations
# Processed ./train/labels\0796.csv, found 1 annotations
# EmptyDataError: ./train/labels\0797.csv
# Processed ./train/labels\0798.csv, found 2 annotations
# Processed ./train/labels\0800.csv, found 1 annotations
# Processed ./train/labels\0802.csv, found 1 annotations
# Processed ./train/labels\0803.csv, found 4 annotations
# Processed ./train/labels\0804.csv, found 2 annotations
# Processed ./train/labels\0805.csv, found 2 annotations
# Processed ./train/labels\0806.csv, found 1 annotations
# Processed ./train/labels\0807.csv, found 4 annotations
# Processed ./train/labels\0808.csv, found 1 annotations
# Processed ./train/labels\0809.csv, found 1 annotations
# Processed ./train/labels\0811.csv, found 1 annotations
# Processed ./train/labels\0812.csv, found 1 annotations
# Processed ./train/labels\0813.csv, found 2 annotations
# Processed ./train/labels\0815.csv, found 2 annotations
# Processed ./train/labels\0816.csv, found 1 annotations
# Processed ./train/labels\0817.csv, found 1 annotations
# Processed ./train/labels\0818.csv, found 2 annotations
# Processed ./train/labels\0819.csv, found 2 annotations
# Processed ./train/labels\0820.csv, found 1 annotations
# Processed ./train/labels\0821.csv, found 3 annotations
# Processed ./train/labels\0822.csv, found 1 annotations
# EmptyDataError: ./train/labels\0824.csv
# Processed ./train/labels\0825.csv, found 5 annotations
# Processed ./train/labels\0826.csv, found 1 annotations
# Processed ./train/labels\0829.csv, found 1 annotations
# Processed ./train/labels\0830.csv, found 1 annotations
# Processed ./train/labels\0832.csv, found 4 annotations
# Processed ./train/labels\0833.csv, found 2 annotations
# Processed ./train/labels\0835.csv, found 1 annotations
# Processed ./train/labels\0836.csv, found 4 annotations
# Processed ./train/labels\0837.csv, found 3 annotations
# Processed ./train/labels\0840.csv, found 3 annotations
# Processed ./train/labels\0841.csv, found 2 annotations
# Processed ./train/labels\0845.csv, found 2 annotations
# Processed ./train/labels\0847.csv, found 2 annotations
# EmptyDataError: ./train/labels\0848.csv
# Processed ./train/labels\0849.csv, found 2 annotations
# Processed ./train/labels\0850.csv, found 2 annotations
# Processed ./train/labels\0851.csv, found 2 annotations
# Processed ./train/labels\0853.csv, found 1 annotations
# Processed ./train/labels\0854.csv, found 1 annotations
# Processed ./train/labels\0855.csv, found 1 annotations
# Processed ./train/labels\0856.csv, found 1 annotations
# Processed ./train/labels\0857.csv, found 1 annotations
# Processed ./train/labels\0858.csv, found 1 annotations
# Processed ./train/labels\0859.csv, found 2 annotations
# Processed ./train/labels\0860.csv, found 2 annotations
# Processed ./train/labels\0861.csv, found 1 annotations
# Processed ./train/labels\0862.csv, found 2 annotations
# Processed ./train/labels\0863.csv, found 1 annotations
# Processed ./train/labels\0865.csv, found 1 annotations
# Processed ./train/labels\0867.csv, found 2 annotations
# EmptyDataError: ./train/labels\0868.csv
# Processed ./train/labels\0869.csv, found 1 annotations
# Processed ./train/labels\0870.csv, found 1 annotations
# Processed ./train/labels\0872.csv, found 1 annotations
# Processed ./train/labels\0873.csv, found 1 annotations
# Processed ./train/labels\0874.csv, found 3 annotations
# Processed ./train/labels\0875.csv, found 2 annotations
# Processed ./train/labels\0877.csv, found 2 annotations
# Processed ./train/labels\0879.csv, found 2 annotations
# Loaded 703 images with annotations
# Processed ./val/labels\0004.csv, found 3 annotations
# Processed ./val/labels\0039.csv, found 2 annotations
# Processed ./val/labels\0045.csv, found 1 annotations
# Processed ./val/labels\0054.csv, found 4 annotations
# Processed ./val/labels\0083.csv, found 1 annotations
# Processed ./val/labels\0088.csv, found 1 annotations
# Processed ./val/labels\0091.csv, found 1 annotations
# Processed ./val/labels\0101.csv, found 1 annotations
# Processed ./val/labels\0131.csv, found 1 annotations
# Processed ./val/labels\0132.csv, found 2 annotations
# Processed ./val/labels\0137.csv, found 2 annotations
# Processed ./val/labels\0139.csv, found 1 annotations
# Processed ./val/labels\0145.csv, found 2 annotations
# Processed ./val/labels\0149.csv, found 1 annotations
# EmptyDataError: ./val/labels\0179.csv
# Processed ./val/labels\0184.csv, found 1 annotations
# Processed ./val/labels\0187.csv, found 1 annotations
# Processed ./val/labels\0188.csv, found 1 annotations
# Processed ./val/labels\0196.csv, found 2 annotations
# Processed ./val/labels\0215.csv, found 1 annotations
# Processed ./val/labels\0216.csv, found 1 annotations
# Processed ./val/labels\0228.csv, found 1 annotations
# Processed ./val/labels\0229.csv, found 1 annotations
# Processed ./val/labels\0239.csv, found 1 annotations
# Processed ./val/labels\0240.csv, found 1 annotations
# Processed ./val/labels\0248.csv, found 1 annotations
# Processed ./val/labels\0257.csv, found 2 annotations
# Processed ./val/labels\0263.csv, found 1 annotations
# Processed ./val/labels\0270.csv, found 1 annotations
# Processed ./val/labels\0272.csv, found 1 annotations
# Processed ./val/labels\0284.csv, found 2 annotations
# Processed ./val/labels\0291.csv, found 1 annotations
# Processed ./val/labels\0297.csv, found 1 annotations
# Processed ./val/labels\0325.csv, found 2 annotations
# EmptyDataError: ./val/labels\0342.csv
# Processed ./val/labels\0343.csv, found 1 annotations
# Processed ./val/labels\0358.csv, found 1 annotations
# Processed ./val/labels\0379.csv, found 1 annotations
# Processed ./val/labels\0385.csv, found 1 annotations
# Processed ./val/labels\0395.csv, found 1 annotations
# Processed ./val/labels\0406.csv, found 1 annotations
# Processed ./val/labels\0413.csv, found 1 annotations
# Processed ./val/labels\0419.csv, found 1 annotations
# Processed ./val/labels\0422.csv, found 1 annotations
# Processed ./val/labels\0428.csv, found 1 annotations
# EmptyDataError: ./val/labels\0442.csv
# Processed ./val/labels\0444.csv, found 2 annotations
# Processed ./val/labels\0479.csv, found 1 annotations
# Processed ./val/labels\0487.csv, found 1 annotations
# Processed ./val/labels\0547.csv, found 2 annotations
# Processed ./val/labels\0560.csv, found 1 annotations
# Processed ./val/labels\0568.csv, found 1 annotations
# Processed ./val/labels\0576.csv, found 1 annotations
# Processed ./val/labels\0585.csv, found 1 annotations
# Processed ./val/labels\0587.csv, found 1 annotations
# Processed ./val/labels\0595.csv, found 2 annotations
# Processed ./val/labels\0617.csv, found 1 annotations
# Processed ./val/labels\0652.csv, found 3 annotations
# Processed ./val/labels\0656.csv, found 1 annotations
# Processed ./val/labels\0680.csv, found 2 annotations
# Processed ./val/labels\0681.csv, found 2 annotations
# Processed ./val/labels\0691.csv, found 2 annotations
# Processed ./val/labels\0698.csv, found 1 annotations
# Processed ./val/labels\0709.csv, found 1 annotations
# Processed ./val/labels\0710.csv, found 1 annotations
# Processed ./val/labels\0711.csv, found 2 annotations
# Processed ./val/labels\0717.csv, found 1 annotations
# EmptyDataError: ./val/labels\0733.csv
# Processed ./val/labels\0735.csv, found 1 annotations
# Processed ./val/labels\0744.csv, found 3 annotations
# EmptyDataError: ./val/labels\0745.csv
# EmptyDataError: ./val/labels\0748.csv
# Processed ./val/labels\0757.csv, found 2 annotations
# Processed ./val/labels\0766.csv, found 3 annotations
# Processed ./val/labels\0799.csv, found 1 annotations
# Processed ./val/labels\0810.csv, found 1 annotations
# Processed ./val/labels\0823.csv, found 4 annotations
# Processed ./val/labels\0827.csv, found 1 annotations
# Processed ./val/labels\0831.csv, found 1 annotations
# Processed ./val/labels\0834.csv, found 1 annotations
# Processed ./val/labels\0839.csv, found 2 annotations
# Processed ./val/labels\0844.csv, found 1 annotations
# Processed ./val/labels\0846.csv, found 1 annotations
# Processed ./val/labels\0852.csv, found 1 annotations
# Processed ./val/labels\0864.csv, found 1 annotations
# Processed ./val/labels\0871.csv, found 3 annotations
# Processed ./val/labels\0878.csv, found 1 annotations
# Loaded 87 images with annotations
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# Skipping unknown crop for image of size (133, 110)
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# ...
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) forange
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) fvert
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) stop
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) interdiction
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) danger
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) frouge
# torch.Size([3, 224, 224]) unknown
# torch.Size([3, 224, 224]) obligation
# torch.Size([3, 224, 224]) ceder
# torch.Size([3, 224, 224]) unknown

# %%
# calculer le nombre des images de chaque label dans training set
label_counts = count_labels_in_dataset(dataset)
print("Label counts in traingset:")
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Skipping unknown crop for image of size (133, 110)
# Label counts in traingset:
# frouge: 79
# unknown: 676
# ceder: 120
# interdiction: 288
# fvert: 94
# stop: 98
# danger: 155
# obligation: 106
# forange: 56

# %%
label_counts = count_labels_in_dataset(val_dataset)
print("Label counts in validation dataset:")
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Label counts in validation dataset:
# frouge: 13
# interdiction: 33
# ceder: 16
# obligation: 14
# stop: 14
# danger: 17
# forange: 5
# unknown: 6
# fvert: 2

# %%
def initialize_model(num_classes, use_pretrained=True):
    model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT if use_pretrained else None)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    return model

def train_model(model, criterion, optimizer, dataloader, num_epochs=25):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in dataloader:
            inputs = torch.stack(inputs).to(device)
            labels = torch.tensor([label_to_idx[label] for label in labels]).to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * inputs.size(0)
        
        epoch_loss = running_loss / len(dataloader.dataset)
        print(f'Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}')

    print('Training complete')

# évaluer le modèle
def evaluate_model(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    num_images = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = torch.stack(inputs).to(device)
            labels = torch.tensor([label_to_idx[label] for label in labels]).to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            num_images += len(inputs)
            
    accuracy = 100 * correct / total if total > 0 else None
    print(f'Accuracy: {accuracy:.2f}%' if accuracy is not None else "Accuracy calculation failed")
    print(f'Total images validated: {num_images}')
    return accuracy


#définir les labels
label_to_idx = {label: idx for idx, label in enumerate(["danger", "interdiction", "obligation", "stop", "ceder", "frouge", "forange", "fvert", "unknown"])}
idx_to_label = {idx: label for label, idx in label_to_idx.items()}

# initialiser le modèle
num_classes = 9
model = initialize_model(num_classes, use_pretrained=False)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
#définir la fonction de perte et l'optimiseur
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

train_model(model, criterion, optimizer, dataloader)
# Out:
# Skipping unknown crop for image of size (133, 110)
# Epoch 0/24, Loss: 3.5043
# Skipping unknown crop for image of size (133, 110)
# Epoch 1/24, Loss: 2.1733
# Skipping unknown crop for image of size (133, 110)
# Epoch 2/24, Loss: 1.7960
# Skipping unknown crop for image of size (133, 110)
# Epoch 3/24, Loss: 1.3062
# Skipping unknown crop for image of size (133, 110)
# Epoch 4/24, Loss: 1.3224
# Skipping unknown crop for image of size (133, 110)
# Epoch 5/24, Loss: 1.0061
# Skipping unknown crop for image of size (133, 110)
# Epoch 6/24, Loss: 0.9116
# Skipping unknown crop for image of size (133, 110)
# Epoch 7/24, Loss: 0.7694
# Skipping unknown crop for image of size (133, 110)
# Epoch 8/24, Loss: 0.6542
# Skipping unknown crop for image of size (133, 110)
# Epoch 9/24, Loss: 0.5402
# Skipping unknown crop for image of size (133, 110)
# Epoch 10/24, Loss: 0.4695
# Skipping unknown crop for image of size (133, 110)
# Epoch 11/24, Loss: 0.4545
# Skipping unknown crop for image of size (133, 110)
# Epoch 12/24, Loss: 0.4063
# Skipping unknown crop for image of size (133, 110)
# Epoch 13/24, Loss: 0.3678
# Skipping unknown crop for image of size (133, 110)
# Epoch 14/24, Loss: 0.3503
# Skipping unknown crop for image of size (133, 110)
# Epoch 15/24, Loss: 0.3295
# Skipping unknown crop for image of size (133, 110)
# Epoch 16/24, Loss: 0.3302
# Skipping unknown crop for image of size (133, 110)
# Epoch 17/24, Loss: 0.3126
# Skipping unknown crop for image of size (133, 110)
# Epoch 18/24, Loss: 0.2784
# Skipping unknown crop for image of size (133, 110)
# Epoch 19/24, Loss: 0.2726
# Skipping unknown crop for image of size (133, 110)
# Epoch 20/24, Loss: 0.2086
# Skipping unknown crop for image of size (133, 110)
# Epoch 21/24, Loss: 0.1612
# Skipping unknown crop for image of size (133, 110)
# Epoch 22/24, Loss: 0.1452
# Skipping unknown crop for image of size (133, 110)
# Epoch 23/24, Loss: 0.1403
# Skipping unknown crop for image of size (133, 110)
# Epoch 24/24, Loss: 0.2128
# Training complete

# %%
torch.save(model.state_dict(), 'resnet18_road_sign_model.pth')

# %%
#vgg16
def initialize_vgg16_model(num_classes, use_pretrained=True):
    model = models.vgg16(weights=models.VGG16_Weights.DEFAULT if use_pretrained else None)
    num_ftrs = model.classifier[6].in_features
    model.classifier[6] = nn.Linear(num_ftrs, num_classes)
    return model

# initializer le modèle VGG16
model_vgg16 = initialize_vgg16_model(num_classes, use_pretrained=False)
model_vgg16 = model_vgg16.to(device)

# entraîner le modèle vgg16
train_model(model_vgg16, criterion, optimizer, dataloader)

torch.save(model_vgg16.state_dict(), 'vgg16_road_sign_model.pth')
# Out:
# Skipping unknown crop for image of size (133, 110)
# Epoch 0/24, Loss: 5.2234
# Skipping unknown crop for image of size (133, 110)
# Epoch 1/24, Loss: 5.2160
# Skipping unknown crop for image of size (133, 110)
# Epoch 2/24, Loss: 5.2262
# Skipping unknown crop for image of size (133, 110)
# Epoch 3/24, Loss: 5.2304
# Skipping unknown crop for image of size (133, 110)
# Epoch 4/24, Loss: 5.2174
# Skipping unknown crop for image of size (133, 110)
# Epoch 5/24, Loss: 5.2205
# Skipping unknown crop for image of size (133, 110)
# Epoch 6/24, Loss: 5.2238
# Skipping unknown crop for image of size (133, 110)
# Epoch 7/24, Loss: 5.2265
# Skipping unknown crop for image of size (133, 110)
# Epoch 8/24, Loss: 5.2238
# Skipping unknown crop for image of size (133, 110)
# Epoch 9/24, Loss: 5.2187
# Skipping unknown crop for image of size (133, 110)
# Epoch 10/24, Loss: 5.2111
# Skipping unknown crop for image of size (133, 110)
# Epoch 11/24, Loss: 5.2196
# Skipping unknown crop for image of size (133, 110)
# Epoch 12/24, Loss: 5.2288
# Skipping unknown crop for image of size (133, 110)
# Epoch 13/24, Loss: 5.2165
# Skipping unknown crop for image of size (133, 110)
# Epoch 14/24, Loss: 5.2238
# Skipping unknown crop for image of size (133, 110)
# Epoch 15/24, Loss: 5.2163
# Skipping unknown crop for image of size (133, 110)
# Epoch 16/24, Loss: 5.2244
# Skipping unknown crop for image of size (133, 110)
# Epoch 17/24, Loss: 5.2207
# Skipping unknown crop for image of size (133, 110)
# Epoch 18/24, Loss: 5.2209
# Skipping unknown crop for image of size (133, 110)
# Epoch 19/24, Loss: 5.2242
# Skipping unknown crop for image of size (133, 110)
# Epoch 20/24, Loss: 5.2175
# Skipping unknown crop for image of size (133, 110)
# Epoch 21/24, Loss: 5.2178
# Skipping unknown crop for image of size (133, 110)
# Epoch 22/24, Loss: 5.2183
# Skipping unknown crop for image of size (133, 110)
# Epoch 23/24, Loss: 5.2429
# Skipping unknown crop for image of size (133, 110)
# Epoch 24/24, Loss: 5.2152
# Training complete

# %%
def initialize_densenet_model(num_classes, use_pretrained=True):
    model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT if use_pretrained else None)
    num_ftrs = model.classifier.in_features
    model.classifier = nn.Linear(num_ftrs, num_classes)
    return model

model_densenet = initialize_densenet_model(num_classes, use_pretrained=False)
model_densenet = model_densenet.to(device)

train_model(model_densenet, criterion, optimizer, dataloader)

torch.save(model_densenet.state_dict(), 'densenet_road_sign_model.pth')
# Out:
# Skipping unknown crop for image of size (133, 110)
# Epoch 0/24, Loss: 5.2255
# Skipping unknown crop for image of size (133, 110)
# Epoch 1/24, Loss: 5.2013
# Skipping unknown crop for image of size (133, 110)
# Epoch 2/24, Loss: 5.2218
# Skipping unknown crop for image of size (133, 110)
# Epoch 3/24, Loss: 5.2155
# Skipping unknown crop for image of size (133, 110)
# Epoch 4/24, Loss: 5.1872
# Skipping unknown crop for image of size (133, 110)
# Epoch 5/24, Loss: 5.2037
# Skipping unknown crop for image of size (133, 110)
# Epoch 6/24, Loss: 5.2225
# Skipping unknown crop for image of size (133, 110)
# Epoch 7/24, Loss: 5.2215
# Skipping unknown crop for image of size (133, 110)
# Epoch 8/24, Loss: 5.1911
# Skipping unknown crop for image of size (133, 110)
# Epoch 9/24, Loss: 5.2135
# Skipping unknown crop for image of size (133, 110)
# Epoch 10/24, Loss: 5.2131
# Skipping unknown crop for image of size (133, 110)
# Epoch 11/24, Loss: 5.2145
# Skipping unknown crop for image of size (133, 110)
# Epoch 12/24, Loss: 5.2086
# Skipping unknown crop for image of size (133, 110)
# Epoch 13/24, Loss: 5.1955
# Skipping unknown crop for image of size (133, 110)
# Epoch 14/24, Loss: 5.1985
# Skipping unknown crop for image of size (133, 110)
# Epoch 15/24, Loss: 5.2212
# Skipping unknown crop for image of size (133, 110)
# Epoch 16/24, Loss: 5.2157
# Skipping unknown crop for image of size (133, 110)
# Epoch 17/24, Loss: 5.2023
# Skipping unknown crop for image of size (133, 110)
# Epoch 18/24, Loss: 5.2066
# Skipping unknown crop for image of size (133, 110)
# Epoch 19/24, Loss: 5.2191
# Skipping unknown crop for image of size (133, 110)
# Epoch 20/24, Loss: 5.1998
# Skipping unknown crop for image of size (133, 110)
# Epoch 21/24, Loss: 5.2177
# Skipping unknown crop for image of size (133, 110)
# Epoch 22/24, Loss: 5.2161
# Skipping unknown crop for image of size (133, 110)
# Epoch 23/24, Loss: 5.2241
# Skipping unknown crop for image of size (133, 110)
# Epoch 24/24, Loss: 5.2361
# Training complete

# %%
def initialize_resnet18_model(num_classes, use_pretrained=False):
    model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT if use_pretrained else None)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    return model

def initialize_vgg16_model(num_classes, use_pretrained=False):
    model = models.vgg16(weights=models.VGG16_Weights.DEFAULT if use_pretrained else None)
    num_ftrs = model.classifier[6].in_features
    model.classifier[6] = nn.Linear(num_ftrs, num_classes)
    return model

def initialize_densenet_model(num_classes, use_pretrained=False):
    model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT if use_pretrained else None)
    num_ftrs = model.classifier.in_features
    model.classifier = nn.Linear(num_ftrs, num_classes)
    return model
model_initializers = {
    'resnet18': initialize_resnet18_model,
    'vgg16': initialize_vgg16_model,
    'densenet': initialize_densenet_model,
}
results = {}
# model_names = ['resnet18','vgg16', 'inception', 'densenet']
for model_name, initialize_model in model_initializers.items():
    model = initialize_model(num_classes, use_pretrained=False)
    model.load_state_dict(torch.load(f'{model_name}_road_sign_model.pth'))
    model = model.to(device)
    print(f'Evaluating {model_name} model...')
    accuracy = evaluate_model(model, val_dataloader)
    results[model_name] = accuracy
# Out:
# Evaluating resnet18 model...
# Accuracy: 92.50%
# Total images validated: 120
# Evaluating vgg16 model...
# Accuracy: 1.67%
# Total images validated: 120
# Evaluating densenet model...
# Accuracy: 8.33%
# Total images validated: 120
